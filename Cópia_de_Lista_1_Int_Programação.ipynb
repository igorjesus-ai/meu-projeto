# %% [markdown]
# <a href="https://colab.research.google.com/github/igorjesus-ai/meu-projeto/blob/main/C%C3%B3pia_de_Lista_1_Int_Programa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# exercício 1
n1 = float(input("digite a nota da primeira avaliação: "))
n2 = float(input("digite a nota da segunda avaliação:"))
media = (n1+n2)/2
if media == 10:
  status = "aprovado com distinção"
  print(f" A média final do aluno foi de {media} pontos. Situação final: {status}")
elif media >= 7 and media < 10:
  status = "aprovado"
  print(f" A média final do aluno foi de {media} pontos. Situação final: {status}")
elif media < 7:
  status = "reprovado"
  print(f" A média final do aluno foi de {media} pontos. Situação final: {status}")
if media > 10 or media < 0:
  print("Erro, insira notas entre 0 e 10")
# Out:
# digite a nota da primeira avaliação: 10
# digite a nota da segunda avaliação:8
#  A média final do aluno foi de 9.0 pontos. Situação final: aprovado

# %%
# exercício 2(extra)
maior = 0
menor = 0
total = int(input("quantos valores serão cadastrados?  "))
for qualquer in range (1, total+1):
  n = int(input("digite um número qualquer maior que 0 (digite -1 para sair):  "))
  if qualquer == 1:
    maior = n
    menor = n
  else:
    if n > maior:
      maior = n
    if n < menor:
      menor = n
print(f" O maior numero foi: {maior} e o menor número foi: {menor}")
# Out:
# quantos valores serão cadastrados?  -1
#  O maior numero foi: 0 e o menor número foi: 0

# %%
#exercício 3 - reajuste de salário

salario_atual = int(input("digite seu salário atual: \n"))
print("\n" + "="*165)
titulo = "SISTEMA DE REAJUSTE SALARIAL"
print(titulo.center(165))
if salario_atual == 1500:
  reajuste = (salario_atual + (salario_atual*20)/100)
  percentual = "20%"
  aumento = (salario_atual*20)/100
elif salario_atual > 1500 and salario_atual <= 3000:
  reajuste = (salario_atual + (salario_atual*10)/100)
  percentual = "10%"
  aumento = (salario_atual*10)/100
elif salario_atual > 3000:
  reajuste = (salario_atual + (salario_atual*5)/100)
  percentual = "5%"
  aumento = (salario_atual*5)/100
print(f"Salário antes do reajuste:{salario_atual:,.2f}")
print(f"Percentual aplicado: {percentual}")
print(f"Valor de aumento: {aumento:,.2f}")
print(f"Salário novo:{reajuste:,.2f}")
# Out:
# digite seu salário atual:
# 8462
#
# ...
#                                                                      SISTEMA DE REAJUSTE SALARIAL
# Salário antes do reajuste:8,462.00
# Percentual aplicado: 5%
# Valor de aumento: 423.10
# Salário novo:8,885.10

# %%
# exercício 4 - pesquisador do CEIA
horas = int(input("Qual é a sua carga horária mensal?  "))
bolsa_ceia = float(input("Quanto recebe atualmente?  "))
valor = float(input("Digite o seu salário atual ou o salário almejado:  "))
hora_trabalho = float(valor/horas)
INSS = (valor*10)/100
porc = 0
comparacao = 0
if valor == 1900:
  print("você está isento de imposto de renda")
  porc = 0
  liquido = (valor-porc)
elif valor > 1900 and valor <= 2800:
  porc = (valor*7.5)/100
  liquido = (valor-porc)
elif valor > 2800 and valor <=3700:
  porc = (valor*15)/100
  liquido = (valor-porc)
elif valor > 3700:
  porc = (valor*20)/100
  liquido = (valor-porc)


print(165*"-")

("                                                                     SIMULADOR SALARIAL                                                                      ")

print(f"Seu salário bruto é igual a: {valor}")

print(f"O imposto de renda é igual a: {porc}")

print(f"O valor do INSS é igual a: {INSS}")

print (f" Seu salário líquido é igual a:{liquido}")

if bolsa_ceia > valor:
   comparacao = (bolsa_ceia - valor)
   print (f"Em comparação com o valor da sua renda atual, você receberá ${comparacao} a menos")
elif valor > bolsa_ceia:
   comparacao = (valor - bolsa_ceia)
   print (f"Em comparação com o valor da sua renda atual, você receberá ${comparacao} a mais")
# Out:
# Qual é a sua carga horária mensal?  40
# Quanto recebe atualmente?  3800
# Digite o seu salário atual ou o salário almejado:  300
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Seu salário bruto é igual a: 300.0
# O imposto de renda é igual a: 0
# O valor do INSS é igual a: 30.0
#  Seu salário líquido é igual a:16000.0
# Em comparação com o valor da sua renda atual, você receberá $3500.0 a menos

# %%
# Caixa eletrônico
saque = int(input("Quanto deseja sacar da sua conta hoje?  "))
valor = saque
contador_nota = 0
cedula = 100

while True:
  if valor >= cedula:
    valor -= cedula
    contador_nota += 1
  else:
    print(f"O total de {contador_nota} cedula de ${cedula}")
    if cedula == 100:
      cedula = 50
    elif cedula == 50:
      cedula = 10
    elif cedula == 10:
      cedula = 5
    elif cedula == 5:
      cedula = 1
    contador_nota = 0
    if valor == 0:
      break
    if valor < 0:
      break
# Out:
# Quanto deseja sacar da sua conta hoje?  -7
# O total de 0 cedula de $100

# %%
# Conta telefônica

minutos = int(input("Quantos minutos você utilizou esse mês?"))
if minutos <= 100:
  preco = 0.20
elif minutos >= 100 and minutos <= 200:
  preco = 0.18
elif minutos > 200:
  preco = 0.15

valor_pago = minutos*preco
print(f"O valor da fatura telefônica desse mês é de ${valor_pago:,.2f}")
# Out:
# Quantos minutos você utilizou esse mês?456
# O valor da fatura telefônica desse mês é de $68.40

# %%
# calculadora simples
print(165*"=")
print("Calculadora simples".center(165))
n1 = float(input("digite um número qualquer:  "))
n2 = float(input("digite outro número qualquer:  "))
print (" soma = 1; subtração = 2; multiplicação = 3; divisão = 4")
operacao = str(input("qual operação deseja realizar?  "))
if operacao == "1":
  resultado = n1+n2
elif operacao =="3":
  resultado = n1*n2
elif operacao == "4":
  resultado = n1/n2
elif operacao == "2":
  resultado = n1-n2
print(f"o resultado da operação escolhida entre os números é: {resultado}")
# Out:
# ...
#                                                                          Calculadora simples
# digite um número qualquer:  10
# digite outro número qualquer:  5
#  soma = 1; subtração = 2; multiplicação = 3; divisão = 4
# qual operação deseja realizar?  4
# o resultado da operação escolhida entre os números é: 2.0

# %%
# Triângulos
m1 = float(input("Digite a medida de um dos 3 lados: "))
m2 = float(input("Digite a medida de um dos 2 lados restantes: "))
m3 = float(input("Digite a medida do último lado: "))

if m1 < m2+m3 and m2<m1+m3 and m3<m1+m2:
  resposta = ("Esses segmentos podem formar um triângulo ")
  if m1==m2==m3:
    tipo = "equilátero"
  elif m1 == m2 or m1 == m3 or m2 == m3:
    tipo = "isósceles"
  else:
    tipo = "escaleno"
  print(f"{resposta} do tipo {tipo} ")
else:
  print("Impossível formar um triângulo com essas medidas")
# Out:
# Digite a medida de um dos 3 lados: 3
# Digite a medida de um dos 2 lados restantes: 4
# Digite a medida do último lado: 5
# Esses segmentos podem formar um triângulo  do tipo escaleno

# %%
contador = 0

p1= input("O sistema parou de responder?")
if p1=="sim":
  contador+=1
p2= input("Houve perda de dados?")
if p2=="sim":
  contador+=1
p3= input("O problema afetou mais de um usuário?")
if p3=="sim":
  contador+=1
p4= input("O erro ocorreu mais de uma vez no mesmo dia?")
if p4=="sim":
  contador+=1
p5= input("Foi necessário interromper uma atividade importante?")
if p5=="sim":
  contador+=1
#crítico
if contador == 1 or contador ==0:
  r = ("Sem indícios de criticidade")
elif contador == 2:
  r = ("baixa criticidade")
elif contador == 3 or contador == 4:
  r =("Média criticidade")
elif contador == 5:
  r= ("Alta criticidade")
print(r)
# Out:
# O sistema parou de responder?não
# Houve perda de dados?sim
# O problema afetou mais de um usuário?não
# O erro ocorreu mais de uma vez no mesmo dia?sim
# Foi necessário interromper uma atividade importante?não
# baixa criticidade
